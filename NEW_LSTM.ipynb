# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import itertools
import pickle, gzip
import gc
import time

# %%
def time_kernel(diff, tau):
    return np.exp(-diff ** 2 / (2 * tau ** 2))

# %%
train_series = pd.read_csv('training_set.csv')
metadata_train = pd.read_csv('training_set_metadata.csv')

simple_features = train_series.groupby(
    ['object_id', 'passband'])['flux'].agg(
    ['mean', 'median', 'max', 'min', 'std']).unstack('passband')


#construct time series using binned observations:
ts_mod = train_series[['object_id', 'mjd', 'passband', 'flux']].copy()
#bin by 5 days, reducing the size of data but still giving a time series
ts_mod['mjd_d5'] = (ts_mod['mjd'] / 5).astype(int)
ts_mod = ts_mod.groupby(['object_id', 'mjd_d5', 'passband'])['flux'].mean().reset_index()

#pivotting
ts_piv = pd.pivot_table(ts_mod, 
                        index='object_id', 
                        columns=['mjd_d5', 'passband'], 
                        values=['flux'],
                        dropna=False)

gc.enable()

# %%
t_min, t_max = train_series['mjd'].min(), train_series['mjd'].max()
sample_points = np.array(np.arange(t_min, t_max, 20))

weights = time_kernel(np.expand_dims(sample_points, 0) 
                      - np.expand_dims(train_series['mjd'].values, 1), 5)
ts_mod_sw = train_series[['object_id', 'mjd', 'passband', 'flux']].copy()
for i in range(len(sample_points)):
    ts_mod_sw[f'sw_{i}'] = weights[:, i]

# %%
def group_transform(chunk):
    sample_weights = chunk[[f'sw_{i}' for i in range(len(sample_points))]]
    sample_weights /= np.sum(sample_weights, axis=0)
    weighted_flux = np.expand_dims(chunk['flux'].values, 1) * sample_weights.fillna(0)
    return np.sum(weighted_flux, axis=0)

# %%
ts_mod_sw = ts_mod_sw.groupby(
    ['object_id', 'passband']).apply(group_transform)

# %%
del metadata_train['ra'],metadata_train['decl'],metadata_train['gal_l'], metadata_train['gal_b'],metadata_train['hostgal_photoz'],metadata_train['hostgal_photoz_err'], metadata_train['distmod'], metadata_train['mwebv']
#Bin into ddf and non-ddf training
ddf = metadata_train[(metadata_train['ddf'] == 1)]
del ddf['ddf']

ddf_far_away= (ddf[(ddf['hostgal_specz'] > 0)])
ddf_far_away.set_index('object_id', inplace=True)
ddf_nearby= ddf[(ddf['hostgal_specz'] <=0)]
ddf_nearby.set_index('object_id', inplace=True)
non_ddf = metadata_train[(metadata_train['ddf'] == 0)]
del non_ddf['ddf']

non_ddf_far_away= non_ddf[(non_ddf['hostgal_specz'] >0)]
non_ddf_far_away.set_index('object_id', inplace=True)
non_ddf_nearby= non_ddf[(non_ddf['hostgal_specz'] <=0 )]
non_ddf_nearby.set_index('object_id', inplace=True)
del ddf, non_ddf, ddf_far_away['hostgal_specz'], non_ddf_far_away['hostgal_specz'], ddf_nearby['hostgal_specz'], non_ddf_nearby['hostgal_specz']

gc.collect()

bins = [ddf_far_away, ddf_nearby, non_ddf_far_away, non_ddf_nearby]

# %%
def get_data_point(object_id, bin_name):
    x = ts_mod_sw.loc[object_id].values.reshape(-1, 6)
#     mu = np.mean(x, axis=0)
#     sigma = np.std(x, axis=0)
#     x = torch.tensor((x-mu)/sigma, dtype=torch.float32)
    x = torch.tensor(x, dtype=torch.float32)
    x[x != x] = 0
    y = torch.tensor([classes.index(bin_name.loc[object_id].target)])
    return x, y

def random_data_point(bin_name):
    object_id = bin_name.sample().index.values[0]
    return get_data_point(object_id, bin_name)

# %%
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, batch_size=1):
        super(RNN, self).__init__()

        self.hidden_dim = hidden_size
        self.batch_size = batch_size
        #TODO add dropout or something
        self.lstm = nn.LSTM(input_size, hidden_size, dropout=.5, num_layers=2)
        self.hidden2out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)
        self.hidden = self.init_hidden()
    
    def forward(self, sequence):
        x = sequence.view(len(sequence), self.batch_size , -1)
        lstm_out, self.hidden = self.lstm(x, self.hidden)
        output  = self.hidden2out(lstm_out[-1])
        output = self.softmax(output)
        return output

    def init_hidden(self):
        return (torch.zeros(2, self.batch_size, self.hidden_dim),
                torch.zeros(2, self.batch_size, self.hidden_dim))

# %%
classes = tuple(metadata_train.target.unique())

# %%
def categoryFromOutput(output):
    top_n, top_i = output.topk(1)
    category_i = top_i[0].item()
    return classes[category_i], category_i

# %%
def predict(model, bin_name, sample=1):
    
    vc = bin_name.target.value_counts(normalize=True)
    weights = torch.tensor([1-(vc.loc[i]) if i in vc.index else 1 for i in classes])
    
    labels = []
    loss = 0
    criterion = nn.NLLLoss()
    s = bin_name.sample(frac=sample)
    with torch.no_grad():
        for obj_id in s.index:
            x, y = get_data_point(obj_id, s)
            y_hat = model(x)
            label = categoryFromOutput(y_hat)[0]
            labels.append([obj_id, label, bin_name.loc[obj_id].target])
            loss += criterion(y_hat, y)

    print("Average Loss: {:.2f}".format(loss/len(s)))
    labels= pd.DataFrame(labels, columns=["object_id", "y_pred", "y_true"])
    labels.set_index("object_id", inplace=True)
    return labels, loss/len(s)

# %%
def up_sample(bin_name, n=None):
    from sklearn.utils import resample
    classes = bin_name.target.unique()
    class_dfs = [bin_name[bin_name.target == class_] for class_ in classes]
    if not n:
        n = np.max([len(df) for df in class_dfs])
    even_dfs = [resample(df,
                        replace=True,
                        n_samples=n) for df in class_dfs]
    return pd.concat(even_dfs).sample(frac=1).reset_index()

# %%
def train(train_bin_name, valid_bin_name, n_samples=None, epochs=1, verbose=True):
    
    # Initialize Model
    print("Building LSTM model..")
    model = RNN(6, 128, 14)
    criterion = nn.NLLLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.001, momentum = .9, nesterov=True)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5, verbose=verbose, patience=2)
    print("Done.")
    print_every = 100
    
    train_loss = []
    valid_loss = []
    min_loss = np.inf

    start_t = time.time()
    
    for epoch in range(epochs):
        current_loss = 0
        randomized_bin = up_sample(train_bin_name, n=n_samples)
        n = len(randomized_bin)
        for i, row in randomized_bin.iterrows():
            # Step 1. Remember that Pytorch accumulates gradients.
            # We need to clear them out before each instance
            model.zero_grad()
            
            # Also, we need to clear out the hidden state of the LSTM,
            # detaching it from its history on the last instance.
            model.hidden = model.init_hidden()

            # Step 2. Get our inputs ready for the network, that is, turn them into
            # Tensors of light curve inputs.
            obj_id = row['object_id']
            x_train, y_train = get_data_point(obj_id, train_bin_name)

            # Step 3. Run our forward pass.
            y_hat = model(x_train)

            # Step 4. Compute the loss, gradients, and update the parameters by
            #  calling optimizer.step()
            loss = criterion(y_hat, y_train)
            current_loss += loss
            loss.backward()
            optimizer.step()
            
            if ((i+1)%print_every == 0 and verbose):
                print("Epoch {} {:.0f}% ===> Avg Loss: {:.3f}".format(epoch, (i/n*100), current_loss/print_every))
                current_loss=0
                
        # After each epoch test on validation data
        print("Epoch {}: Validation".format(epoch), end =" ")
        _, vloss = predict(model, valid_bin_name)
#         print("Epoch {}: Training".format(epoch), end =" ")
#         _, tloss = predict(model, train_bin_name)
        valid_loss.append(vloss)
#         train_loss.append(tloss)
        
        # Give it to the scheduler to see if learning rate needs to be reduced
        scheduler.step(vloss)
        
        if vloss < min_loss:
            min_loss = vloss
            print(f"         Model achieved record validation loss, Saving to {start_t}_E{epoch}_L{vloss}.pt")
            torch.save(model.state_dict(), f'models/{start_t}_E{epoch}_L{vloss}.pt')
            print("         Done.")
            
    print(f"Finished {epochs} epochs in {time.time() - start_t}")
    return model, valid_loss, train_loss

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import warnings

# %%
# Split into validation and training.
ddf_far_away_train, ddf_far_away_validation = train_test_split(ddf_far_away, test_size=0.3)
ddf_nearby_train, ddf_nearby_validation = train_test_split(ddf_nearby, test_size=0.3)
    
non_ddf_far_away_train, non_ddf_far_away_validation = train_test_split(non_ddf_far_away, test_size=0.3)
non_ddf_nearby_train, non_ddf_nearby_validation = train_test_split(non_ddf_nearby, test_size=0.3)
    
# Bin up
training_bin = [ddf_far_away_train, ddf_nearby_train, 
                non_ddf_far_away_train, non_ddf_nearby_train]

validation_bin = [ddf_far_away_validation, ddf_nearby_validation, 
                   non_ddf_far_away_validation, non_ddf_nearby_validation]

# filenames = ['ddf_far_away', 'ddf_nearby', 'non_ddf_far_away', 'non_ddf_nearby']

# %%
model = train(ddf_far_away_train, ddf_far_away_validation, epochs=10, n_samples=500)
# Out:
# Building LSTM model..
# Done.
# Epoch 0 2% ===> Avg Loss: 2.599
# Epoch 0 4% ===> Avg Loss: 2.534
# Epoch 0 7% ===> Avg Loss: 2.474
# Epoch 0 9% ===> Avg Loss: 2.397
# Epoch 0 11% ===> Avg Loss: 2.366
# Epoch 0 13% ===> Avg Loss: 2.292
# Epoch 0 16% ===> Avg Loss: 2.248
# Epoch 0 18% ===> Avg Loss: 2.173
# Epoch 0 20% ===> Avg Loss: 2.076
# Epoch 0 22% ===> Avg Loss: 2.058
# Epoch 0 24% ===> Avg Loss: 2.081
# Epoch 0 27% ===> Avg Loss: 2.054
# Epoch 0 29% ===> Avg Loss: 2.029
# Epoch 0 31% ===> Avg Loss: 1.850
# Epoch 0 33% ===> Avg Loss: 1.890
# Epoch 0 36% ===> Avg Loss: 1.851
# Epoch 0 38% ===> Avg Loss: 1.747
# Epoch 0 40% ===> Avg Loss: 1.857
# Epoch 0 42% ===> Avg Loss: 1.670
# Epoch 0 44% ===> Avg Loss: 1.677
# Epoch 0 47% ===> Avg Loss: 1.704
# Epoch 0 49% ===> Avg Loss: 1.685
# Epoch 0 51% ===> Avg Loss: 1.477
# Epoch 0 53% ===> Avg Loss: 1.581
# Epoch 0 56% ===> Avg Loss: 1.564
# Epoch 0 58% ===> Avg Loss: 1.529
# Epoch 0 60% ===> Avg Loss: 1.643
# Epoch 0 62% ===> Avg Loss: 1.636
# Epoch 0 64% ===> Avg Loss: 1.641
# Epoch 0 67% ===> Avg Loss: 1.636
# Epoch 0 69% ===> Avg Loss: 1.505
# Epoch 0 71% ===> Avg Loss: 1.460
# Epoch 0 73% ===> Avg Loss: 1.478
# Epoch 0 76% ===> Avg Loss: 1.427
# Epoch 0 78% ===> Avg Loss: 1.543
# Epoch 0 80% ===> Avg Loss: 1.283
# Epoch 0 82% ===> Avg Loss: 1.633
# Epoch 0 84% ===> Avg Loss: 1.459
# Epoch 0 87% ===> Avg Loss: 1.732
# Epoch 0 89% ===> Avg Loss: 1.581
# Epoch 0 91% ===> Avg Loss: 1.672
# Epoch 0 93% ===> Avg Loss: 1.582
# Epoch 0 96% ===> Avg Loss: 1.519
# Epoch 0 98% ===> Avg Loss: 1.566
# Epoch 0 100% ===> Avg Loss: 1.381
# Epoch 0: Validation Average Loss: 1.60
#          Model achieved record validation loss, Saving to 1544153335.3727958_E0_L1.5954276323318481.pt
#          Done.
# Epoch 1 2% ===> Avg Loss: 1.493
# Epoch 1 4% ===> Avg Loss: 1.425
# Epoch 1 7% ===> Avg Loss: 1.540
# Epoch 1 9% ===> Avg Loss: 1.490
# Epoch 1 11% ===> Avg Loss: 1.478
# Epoch 1 13% ===> Avg Loss: 1.383
# Epoch 1 16% ===> Avg Loss: 1.453
# Epoch 1 18% ===> Avg Loss: 1.492
# Epoch 1 20% ===> Avg Loss: 2.543
# Epoch 1 22% ===> Avg Loss: 2.381
# Epoch 1 24% ===> Avg Loss: 1.906
# Epoch 1 27% ===> Avg Loss: 1.886
# Epoch 1 29% ===> Avg Loss: 1.845
# Epoch 1 31% ===> Avg Loss: 1.764
# Epoch 1 33% ===> Avg Loss: 1.741
# Epoch 1 36% ===> Avg Loss: 1.787
# Epoch 1 38% ===> Avg Loss: 1.826
# Epoch 1 40% ===> Avg Loss: 1.657
# Epoch 1 42% ===> Avg Loss: 1.736
# Epoch 1 44% ===> Avg Loss: 1.724
# Epoch 1 47% ===> Avg Loss: 1.652
# Epoch 1 49% ===> Avg Loss: 1.650
# Epoch 1 51% ===> Avg Loss: 1.663
# Epoch 1 53% ===> Avg Loss: 1.578
# Epoch 1 56% ===> Avg Loss: 1.632
# Epoch 1 58% ===> Avg Loss: 1.556
# Epoch 1 60% ===> Avg Loss: 1.559
# Epoch 1 62% ===> Avg Loss: 1.339
# Epoch 1 64% ===> Avg Loss: 1.549
# Epoch 1 67% ===> Avg Loss: 1.615
# Epoch 1 69% ===> Avg Loss: 1.589
# Epoch 1 71% ===> Avg Loss: 1.584
# Epoch 1 73% ===> Avg Loss: 1.512
# Epoch 1 76% ===> Avg Loss: 1.704
# Epoch 1 78% ===> Avg Loss: 1.597
# Epoch 1 80% ===> Avg Loss: 1.517
# Epoch 1 82% ===> Avg Loss: 1.567
# Epoch 1 84% ===> Avg Loss: 1.379
# Epoch 1 87% ===> Avg Loss: 1.565
# Epoch 1 89% ===> Avg Loss: 1.514
# Epoch 1 91% ===> Avg Loss: 1.482
# Epoch 1 93% ===> Avg Loss: 1.401
# Epoch 1 96% ===> Avg Loss: 1.257
# Epoch 1 98% ===> Avg Loss: 1.270
# Epoch 1 100% ===> Avg Loss: 1.282
# Epoch 1: Validation Average Loss: 2.02
# Epoch 2 2% ===> Avg Loss: 1.339
# Epoch 2 4% ===> Avg Loss: 1.404
# Epoch 2 7% ===> Avg Loss: 1.304
# Epoch 2 9% ===> Avg Loss: 1.334
# Epoch 2 11% ===> Avg Loss: 1.254
# Epoch 2 13% ===> Avg Loss: 1.258
# Epoch 2 16% ===> Avg Loss: 1.342
# Epoch 2 18% ===> Avg Loss: 1.239
# Epoch 2 20% ===> Avg Loss: 1.327
# Epoch 2 22% ===> Avg Loss: 1.289
# Epoch 2 24% ===> Avg Loss: 1.389
# Epoch 2 27% ===> Avg Loss: 1.327
# Epoch 2 29% ===> Avg Loss: 1.478
# Epoch 2 31% ===> Avg Loss: 1.382
# Epoch 2 33% ===> Avg Loss: 1.277
# Epoch 2 36% ===> Avg Loss: 1.371
# Epoch 2 38% ===> Avg Loss: 1.278
# Epoch 2 40% ===> Avg Loss: 1.330
# Epoch 2 42% ===> Avg Loss: 1.314
# Epoch 2 44% ===> Avg Loss: 1.308
# Epoch 2 47% ===> Avg Loss: 1.270
# Epoch 2 49% ===> Avg Loss: 1.316
# Epoch 2 51% ===> Avg Loss: 1.268
# Epoch 2 53% ===> Avg Loss: 1.303
# Epoch 2 56% ===> Avg Loss: 1.143
# Epoch 2 58% ===> Avg Loss: 1.245
# Epoch 2 60% ===> Avg Loss: 1.044
# Epoch 2 62% ===> Avg Loss: 1.116
# Epoch 2 64% ===> Avg Loss: 1.235
# Epoch 2 67% ===> Avg Loss: 1.148
# Epoch 2 69% ===> Avg Loss: 1.553
# Epoch 2 71% ===> Avg Loss: 1.178
# Epoch 2 73% ===> Avg Loss: 1.306
# Epoch 2 76% ===> Avg Loss: 1.080
# Epoch 2 78% ===> Avg Loss: 0.995
# Epoch 2 80% ===> Avg Loss: 1.232
# Epoch 2 82% ===> Avg Loss: 1.299
# Epoch 2 84% ===> Avg Loss: 1.176
# Epoch 2 87% ===> Avg Loss: 1.104
# Epoch 2 89% ===> Avg Loss: 1.210
# Epoch 2 91% ===> Avg Loss: 1.232
# Epoch 2 93% ===> Avg Loss: 1.158
# Epoch 2 96% ===> Avg Loss: 1.254
# Epoch 2 98% ===> Avg Loss: 1.091
# Epoch 2 100% ===> Avg Loss: 1.267
# Epoch 2: Validation Average Loss: 1.72
# Epoch 3 2% ===> Avg Loss: 1.079
# Epoch 3 4% ===> Avg Loss: 1.101
# Epoch 3 7% ===> Avg Loss: 1.017
# Epoch 3 9% ===> Avg Loss: 0.956
# Epoch 3 11% ===> Avg Loss: 1.302
# Epoch 3 13% ===> Avg Loss: 1.182
# Epoch 3 16% ===> Avg Loss: 1.205
# Epoch 3 18% ===> Avg Loss: 1.202
# Epoch 3 20% ===> Avg Loss: 1.020
# Epoch 3 22% ===> Avg Loss: 0.871
# Epoch 3 24% ===> Avg Loss: 1.119
# Epoch 3 27% ===> Avg Loss: 1.016
# Epoch 3 29% ===> Avg Loss: 1.149
# Epoch 3 31% ===> Avg Loss: 0.981
# Epoch 3 33% ===> Avg Loss: 0.992
# Epoch 3 36% ===> Avg Loss: 1.124
# Epoch 3 38% ===> Avg Loss: 1.049
# Epoch 3 40% ===> Avg Loss: 0.934
# Epoch 3 42% ===> Avg Loss: 1.117
# Epoch 3 44% ===> Avg Loss: 1.104
# Epoch 3 47% ===> Avg Loss: 1.029
# Epoch 3 49% ===> Avg Loss: 1.096
# Epoch 3 51% ===> Avg Loss: 1.023
# Epoch 3 53% ===> Avg Loss: 1.135
# Epoch 3 56% ===> Avg Loss: 1.104
# Epoch 3 58% ===> Avg Loss: 1.035
# Epoch 3 60% ===> Avg Loss: 0.995
# Epoch 3 62% ===> Avg Loss: 0.908
# Epoch 3 64% ===> Avg Loss: 1.031
# Epoch 3 67% ===> Avg Loss: 1.072
# Epoch 3 69% ===> Avg Loss: 0.930
# Epoch 3 71% ===> Avg Loss: 0.980
# Epoch 3 73% ===> Avg Loss: 1.016
# Epoch 3 76% ===> Avg Loss: 0.950
# Epoch 3 78% ===> Avg Loss: 1.087
# Epoch 3 80% ===> Avg Loss: 0.949
# Epoch 3 82% ===> Avg Loss: 1.020
# Epoch 3 84% ===> Avg Loss: 0.900
# Epoch 3 87% ===> Avg Loss: 0.942
# Epoch 3 89% ===> Avg Loss: 1.069
# Epoch 3 91% ===> Avg Loss: 0.905
# Epoch 3 93% ===> Avg Loss: 1.140
# Epoch 3 96% ===> Avg Loss: 0.970
# Epoch 3 98% ===> Avg Loss: 0.942
# Epoch 3 100% ===> Avg Loss: 0.759
# Epoch 3: Validation Average Loss: 1.86
# Epoch     3: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 4 2% ===> Avg Loss: 1.042
# Epoch 4 4% ===> Avg Loss: 1.061
# Epoch 4 7% ===> Avg Loss: 1.070
# Epoch 4 9% ===> Avg Loss: 0.874
# Epoch 4 11% ===> Avg Loss: 0.917
# Epoch 4 13% ===> Avg Loss: 0.961
# Epoch 4 16% ===> Avg Loss: 0.946
# Epoch 4 18% ===> Avg Loss: 0.946
# Epoch 4 20% ===> Avg Loss: 0.821
# Epoch 4 22% ===> Avg Loss: 0.905
# Epoch 4 24% ===> Avg Loss: 0.871
# Epoch 4 27% ===> Avg Loss: 0.791
# Epoch 4 29% ===> Avg Loss: 0.905
# Epoch 4 31% ===> Avg Loss: 0.741
# Epoch 4 33% ===> Avg Loss: 0.908
# Epoch 4 36% ===> Avg Loss: 0.942
# Epoch 4 38% ===> Avg Loss: 1.005
# Epoch 4 40% ===> Avg Loss: 0.829
# Epoch 4 42% ===> Avg Loss: 0.887
# Epoch 4 44% ===> Avg Loss: 0.820
# Epoch 4 47% ===> Avg Loss: 0.772
# Epoch 4 49% ===> Avg Loss: 0.757
# Epoch 4 51% ===> Avg Loss: 1.071
# Epoch 4 53% ===> Avg Loss: 0.775
# Epoch 4 56% ===> Avg Loss: 0.955
# Epoch 4 58% ===> Avg Loss: 0.922
# Epoch 4 60% ===> Avg Loss: 0.873
# Epoch 4 62% ===> Avg Loss: 0.716
# Epoch 4 64% ===> Avg Loss: 0.700
# Epoch 4 67% ===> Avg Loss: 0.765
# Epoch 4 69% ===> Avg Loss: 0.915
# Epoch 4 71% ===> Avg Loss: 0.802
# Epoch 4 73% ===> Avg Loss: 0.728
# Epoch 4 76% ===> Avg Loss: 0.767
# Epoch 4 78% ===> Avg Loss: 0.979
# Epoch 4 80% ===> Avg Loss: 0.802
# Epoch 4 82% ===> Avg Loss: 0.845
# Epoch 4 84% ===> Avg Loss: 0.789
# Epoch 4 87% ===> Avg Loss: 0.827
# Epoch 4 89% ===> Avg Loss: 0.825
# Epoch 4 91% ===> Avg Loss: 0.786
# Epoch 4 93% ===> Avg Loss: 0.754
# Epoch 4 96% ===> Avg Loss: 0.910
# Epoch 4 98% ===> Avg Loss: 0.897
# Epoch 4 100% ===> Avg Loss: 0.774
# Epoch 4: Validation Average Loss: 1.59
#          Model achieved record validation loss, Saving to 1544153335.3727958_E4_L1.5913057327270508.pt
#          Done.
# Epoch 5 2% ===> Avg Loss: 0.895
# Epoch 5 4% ===> Avg Loss: 0.800
# Epoch 5 7% ===> Avg Loss: 0.823
# Epoch 5 9% ===> Avg Loss: 0.791
# Epoch 5 11% ===> Avg Loss: 0.910
# Epoch 5 13% ===> Avg Loss: 0.837
# Epoch 5 16% ===> Avg Loss: 0.952
# Epoch 5 18% ===> Avg Loss: 0.966
# Epoch 5 20% ===> Avg Loss: 0.715
# Epoch 5 22% ===> Avg Loss: 0.876
# Epoch 5 24% ===> Avg Loss: 0.721
# Epoch 5 27% ===> Avg Loss: 0.805
# Epoch 5 29% ===> Avg Loss: 0.870
# Epoch 5 31% ===> Avg Loss: 0.750
# Epoch 5 33% ===> Avg Loss: 0.733
# Epoch 5 36% ===> Avg Loss: 0.783
# Epoch 5 38% ===> Avg Loss: 0.869
# Epoch 5 40% ===> Avg Loss: 0.818
# Epoch 5 42% ===> Avg Loss: 0.700
# Epoch 5 44% ===> Avg Loss: 0.771
# Epoch 5 47% ===> Avg Loss: 0.793
# Epoch 5 49% ===> Avg Loss: 0.813
# Epoch 5 51% ===> Avg Loss: 0.755
# Epoch 5 53% ===> Avg Loss: 0.722
# Epoch 5 56% ===> Avg Loss: 0.704
# Epoch 5 58% ===> Avg Loss: 0.729
# Epoch 5 60% ===> Avg Loss: 0.801
# Epoch 5 62% ===> Avg Loss: 0.818
# Epoch 5 64% ===> Avg Loss: 0.696
# Epoch 5 67% ===> Avg Loss: 0.900
# Epoch 5 69% ===> Avg Loss: 0.724
# Epoch 5 71% ===> Avg Loss: 0.777
# Epoch 5 73% ===> Avg Loss: 0.773
# Epoch 5 76% ===> Avg Loss: 0.774
# Epoch 5 78% ===> Avg Loss: 0.664
# Epoch 5 80% ===> Avg Loss: 0.965
# Epoch 5 82% ===> Avg Loss: 0.923
# Epoch 5 84% ===> Avg Loss: 0.905
# Epoch 5 87% ===> Avg Loss: 0.777
# Epoch 5 89% ===> Avg Loss: 0.804
# Epoch 5 91% ===> Avg Loss: 0.751
# Epoch 5 93% ===> Avg Loss: 0.698
# Epoch 5 96% ===> Avg Loss: 0.727
# Epoch 5 98% ===> Avg Loss: 0.715
# Epoch 5 100% ===> Avg Loss: 0.801
# Epoch 5: Validation Average Loss: 1.81
# Epoch 6 2% ===> Avg Loss: 0.797
# Epoch 6 4% ===> Avg Loss: 0.683
# Epoch 6 7% ===> Avg Loss: 0.861
# Epoch 6 9% ===> Avg Loss: 0.811
# Epoch 6 11% ===> Avg Loss: 0.860
# Epoch 6 13% ===> Avg Loss: 0.637
# Epoch 6 16% ===> Avg Loss: 0.695
# Epoch 6 18% ===> Avg Loss: 0.770
# Epoch 6 20% ===> Avg Loss: 0.701
# Epoch 6 22% ===> Avg Loss: 0.796
# Epoch 6 24% ===> Avg Loss: 0.664
# Epoch 6 27% ===> Avg Loss: 0.638
# Epoch 6 29% ===> Avg Loss: 0.796
# Epoch 6 31% ===> Avg Loss: 0.749
# Epoch 6 33% ===> Avg Loss: 0.677
# Epoch 6 36% ===> Avg Loss: 0.850
# Epoch 6 38% ===> Avg Loss: 0.697
# Epoch 6 40% ===> Avg Loss: 0.665
# Epoch 6 42% ===> Avg Loss: 0.741
# Epoch 6 44% ===> Avg Loss: 0.756
# Epoch 6 47% ===> Avg Loss: 0.635
# Epoch 6 49% ===> Avg Loss: 0.729
# Epoch 6 51% ===> Avg Loss: 0.656
# Epoch 6 53% ===> Avg Loss: 0.690
# Epoch 6 56% ===> Avg Loss: 0.806
# Epoch 6 58% ===> Avg Loss: 0.720
# Epoch 6 60% ===> Avg Loss: 0.763
# Epoch 6 62% ===> Avg Loss: 0.720
# Epoch 6 64% ===> Avg Loss: 0.826
# Epoch 6 67% ===> Avg Loss: 0.691
# Epoch 6 69% ===> Avg Loss: 0.561
# Epoch 6 71% ===> Avg Loss: 0.553
# Epoch 6 73% ===> Avg Loss: 0.773
# Epoch 6 76% ===> Avg Loss: 0.775
# Epoch 6 78% ===> Avg Loss: 0.776
# Epoch 6 80% ===> Avg Loss: 0.798
# Epoch 6 82% ===> Avg Loss: 0.644
# Epoch 6 84% ===> Avg Loss: 0.881
# Epoch 6 87% ===> Avg Loss: 0.752
# Epoch 6 89% ===> Avg Loss: 0.771
# Epoch 6 91% ===> Avg Loss: 0.647
# Epoch 6 93% ===> Avg Loss: 0.569
# Epoch 6 96% ===> Avg Loss: 0.636
# Epoch 6 98% ===> Avg Loss: 0.701
# Epoch 6 100% ===> Avg Loss: 0.666
# Epoch 6: Validation Average Loss: 1.55
#          Model achieved record validation loss, Saving to 1544153335.3727958_E6_L1.5507367849349976.pt
#          Done.
# Epoch 7 2% ===> Avg Loss: 0.643
# Epoch 7 4% ===> Avg Loss: 0.582
# Epoch 7 7% ===> Avg Loss: 0.580
# Epoch 7 9% ===> Avg Loss: 0.654
# Epoch 7 11% ===> Avg Loss: 0.632
# Epoch 7 13% ===> Avg Loss: 0.717
# Epoch 7 16% ===> Avg Loss: 0.720
# Epoch 7 18% ===> Avg Loss: 0.599
# Epoch 7 20% ===> Avg Loss: 0.420
# Epoch 7 22% ===> Avg Loss: 0.594
# Epoch 7 24% ===> Avg Loss: 0.593
# Epoch 7 27% ===> Avg Loss: 0.673
# Epoch 7 29% ===> Avg Loss: 0.665
# Epoch 7 31% ===> Avg Loss: 0.508
# Epoch 7 33% ===> Avg Loss: 0.612
# Epoch 7 36% ===> Avg Loss: 0.615
# Epoch 7 38% ===> Avg Loss: 0.718
# Epoch 7 40% ===> Avg Loss: 0.717
# Epoch 7 42% ===> Avg Loss: 0.576
# Epoch 7 44% ===> Avg Loss: 0.683
# Epoch 7 47% ===> Avg Loss: 0.496
# Epoch 7 49% ===> Avg Loss: 0.590
# Epoch 7 51% ===> Avg Loss: 0.591
# Epoch 7 53% ===> Avg Loss: 0.554
# Epoch 7 56% ===> Avg Loss: 0.718
# Epoch 7 58% ===> Avg Loss: 0.642
# Epoch 7 60% ===> Avg Loss: 0.556
# Epoch 7 62% ===> Avg Loss: 0.624
# Epoch 7 64% ===> Avg Loss: 0.611
# Epoch 7 67% ===> Avg Loss: 0.650
# Epoch 7 69% ===> Avg Loss: 0.716
# Epoch 7 71% ===> Avg Loss: 0.547
# Epoch 7 73% ===> Avg Loss: 0.659
# Epoch 7 76% ===> Avg Loss: 0.630
# Epoch 7 78% ===> Avg Loss: 0.761
# Epoch 7 80% ===> Avg Loss: 0.560
# Epoch 7 82% ===> Avg Loss: 0.659
# Epoch 7 84% ===> Avg Loss: 0.804
# Epoch 7 87% ===> Avg Loss: 0.558
# Epoch 7 89% ===> Avg Loss: 0.632
# Epoch 7 91% ===> Avg Loss: 0.599
# Epoch 7 93% ===> Avg Loss: 0.702
# Epoch 7 96% ===> Avg Loss: 0.727
# Epoch 7 98% ===> Avg Loss: 0.607
# Epoch 7 100% ===> Avg Loss: 0.578
# Epoch 7: Validation Average Loss: 1.80
# Epoch 8 2% ===> Avg Loss: 0.595
# Epoch 8 4% ===> Avg Loss: 0.632
# Epoch 8 7% ===> Avg Loss: 0.743
# Epoch 8 9% ===> Avg Loss: 0.524
# Epoch 8 11% ===> Avg Loss: 0.723
# Epoch 8 13% ===> Avg Loss: 0.575
# Epoch 8 16% ===> Avg Loss: 0.730
# Epoch 8 18% ===> Avg Loss: 0.652
# Epoch 8 20% ===> Avg Loss: 0.714
# Epoch 8 22% ===> Avg Loss: 0.665
# Epoch 8 24% ===> Avg Loss: 0.578
# Epoch 8 27% ===> Avg Loss: 0.600
# Epoch 8 29% ===> Avg Loss: 0.675
# Epoch 8 31% ===> Avg Loss: 0.549
# Epoch 8 33% ===> Avg Loss: 0.762
# Epoch 8 36% ===> Avg Loss: 0.550
# Epoch 8 38% ===> Avg Loss: 0.577
# Epoch 8 40% ===> Avg Loss: 0.546
# Epoch 8 42% ===> Avg Loss: 0.588
# Epoch 8 44% ===> Avg Loss: 0.665
# Epoch 8 47% ===> Avg Loss: 0.578
# Epoch 8 49% ===> Avg Loss: 0.451
# Epoch 8 51% ===> Avg Loss: 0.679
# Epoch 8 53% ===> Avg Loss: 0.607
# Epoch 8 56% ===> Avg Loss: 0.649
# Epoch 8 58% ===> Avg Loss: 0.581
# Epoch 8 60% ===> Avg Loss: 0.493
# Epoch 8 62% ===> Avg Loss: 0.562
# Epoch 8 64% ===> Avg Loss: 0.632
# Epoch 8 67% ===> Avg Loss: 0.513
# Epoch 8 69% ===> Avg Loss: 0.597
# Epoch 8 71% ===> Avg Loss: 0.730
# Epoch 8 73% ===> Avg Loss: 0.610
# Epoch 8 76% ===> Avg Loss: 0.436
# Epoch 8 78% ===> Avg Loss: 0.612
# Epoch 8 80% ===> Avg Loss: 0.599
# Epoch 8 82% ===> Avg Loss: 0.523
# Epoch 8 84% ===> Avg Loss: 0.615
# Epoch 8 87% ===> Avg Loss: 0.487
# Epoch 8 89% ===> Avg Loss: 0.669
# Epoch 8 91% ===> Avg Loss: 0.588
# Epoch 8 93% ===> Avg Loss: 0.674
# Epoch 8 96% ===> Avg Loss: 0.544
# Epoch 8 98% ===> Avg Loss: 0.439
# Epoch 8 100% ===> Avg Loss: 0.464
# Epoch 8: Validation Average Loss: 1.75
# Epoch 9 2% ===> Avg Loss: 0.498
# Epoch 9 4% ===> Avg Loss: 0.568
# Epoch 9 7% ===> Avg Loss: 0.558
# Epoch 9 9% ===> Avg Loss: 0.625
# Epoch 9 11% ===> Avg Loss: 0.381
# Epoch 9 13% ===> Avg Loss: 0.517
# Epoch 9 16% ===> Avg Loss: 0.650
# Epoch 9 18% ===> Avg Loss: 0.581
# Epoch 9 20% ===> Avg Loss: 0.573
# Epoch 9 22% ===> Avg Loss: 0.485
# Epoch 9 24% ===> Avg Loss: 0.603
# Epoch 9 27% ===> Avg Loss: 0.680
# Epoch 9 29% ===> Avg Loss: 0.476
# Epoch 9 31% ===> Avg Loss: 0.371
# Epoch 9 33% ===> Avg Loss: 0.503
# Epoch 9 36% ===> Avg Loss: 0.514
# Epoch 9 38% ===> Avg Loss: 0.552
# Epoch 9 40% ===> Avg Loss: 0.645
# Epoch 9 42% ===> Avg Loss: 0.698
# Epoch 9 44% ===> Avg Loss: 0.652
# Epoch 9 47% ===> Avg Loss: 0.406
# Epoch 9 49% ===> Avg Loss: 0.508
# Epoch 9 51% ===> Avg Loss: 0.495
# Epoch 9 53% ===> Avg Loss: 0.477
# Epoch 9 56% ===> Avg Loss: 0.456
# Epoch 9 58% ===> Avg Loss: 0.523
# Epoch 9 60% ===> Avg Loss: 0.465
# Epoch 9 62% ===> Avg Loss: 0.577
# Epoch 9 64% ===> Avg Loss: 0.537
# Epoch 9 67% ===> Avg Loss: 0.533
# Epoch 9 69% ===> Avg Loss: 0.587
# Epoch 9 71% ===> Avg Loss: 0.657
# Epoch 9 73% ===> Avg Loss: 0.383
# Epoch 9 76% ===> Avg Loss: 0.619
# Epoch 9 78% ===> Avg Loss: 0.497
# Epoch 9 80% ===> Avg Loss: 0.554
# Epoch 9 82% ===> Avg Loss: 0.563
# Epoch 9 84% ===> Avg Loss: 0.417
# Epoch 9 87% ===> Avg Loss: 0.508
# Epoch 9 89% ===> Avg Loss: 0.623
# Epoch 9 91% ===> Avg Loss: 0.375
# Epoch 9 93% ===> Avg Loss: 0.544
# Epoch 9 96% ===> Avg Loss: 0.435
# Epoch 9 98% ===> Avg Loss: 0.507
# Epoch 9 100% ===> Avg Loss: 0.536
# Epoch 9: Validation Average Loss: 1.72
# Epoch     9: reducing learning rate of group 0 to 2.5000e-04.
# Finished 10 epochs in 2953.4641201496124

# %%
y_hat, loss = predict(model[0], ddf_far_away_validation)
# Out:
# Average Loss: 1.78

# %%
def confusion(labels, plot=True):
    classes = np.sort(list(labels.y_true.unique()))
    y_pred = np.array(labels.y_pred)
    y_true = np.array(labels.y_true)
    cm=confusion_matrix(y_true, y_pred)
    print(f"Accuracy: {np.trace(cm)/np.sum(cm)}")
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    fig, ax = plt.subplots(figsize=(9,9))
    sns.heatmap(cm, xticklabels=classes, yticklabels=classes, cmap='inferno', annot=True, lw=1, fmt=".2f")
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    if plot:
        plt.show()

def plot_accuracy(train_loss, valid_loss):
    fig_nodes = plt.figure(figsize=(8,8))
    ax1 = fig_nodes.add_subplot(1,1,1)
    ax1.plot(train_acc, marker='o', markersize=5, label = "Training")
    ax1.plot(valid_acc, marker='+', markersize=5, label = "Validation")
    ax1.set_ylim([0,1])
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Accuracy")
    ax1.set_title(f"Training Accuracy wrt Epochs")
    plt.legend()
    plt.show()

# %%
confusion(y_hat)
# Out:
# Accuracy: 0.32558139534883723

# %%
up_sample(ddf_far_away_train)["target"].value_counts()
# Out:
# 95    759
# 67    759
# 15    759
# 90    759
# 62    759
# 42    759
# 88    759
# 64    759
# 52    759
# Name: target, dtype: int64

# %%
model = RNN(6, 32, 14)
model.load_state_dict(torch.load("models/dff_nearby_best.pt"))
model.eval()
# Out:
# RNN(
#   (lstm): LSTM(6, 32, num_layers=2, dropout=0.5)
#   (hidden2out): Linear(in_features=32, out_features=14, bias=True)
#   (softmax): LogSoftmax()
# )
